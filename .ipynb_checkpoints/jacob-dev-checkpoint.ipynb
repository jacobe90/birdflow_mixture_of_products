# %%
from mixture_of_products_validation import track_log_likelihood
import pickle

with open('amewoo_mop_params_48_obs1.0_ent0.0001_dist0.01_pow0.4.pkl', 'rb') as f:
    params = pickle.load(f)

# %%
import pandas as pd
amewoo_track_df = pd.concat([pd.read_csv(
            f"/work/pi_drsheldon_umass_edu/birdflow_modeling/jacob_independent_study/birdflow_black_box/tracks/amewoo-Blomberg-track-data-res-48km.csv"),
                                     pd.read_csv(
                                         f"/work/pi_drsheldon_umass_edu/birdflow_modeling/jacob_independent_study/birdflow_black_box/tracks/amewoo-track-data-res-48km.csv")],
                                    axis=0, ignore_index=True)

# %%
# %%time
tll = track_log_likelihood(params, amewoo_track_df)
print(tll)
# Out:
# row 0 of 10440
# row 20 of 10440
# row 40 of 10440
# row 60 of 10440
# row 80 of 10440
# row 100 of 10440
# row 120 of 10440
# row 140 of 10440
# row 160 of 10440
# row 180 of 10440
# row 200 of 10440
# row 220 of 10440
# row 240 of 10440
# row 260 of 10440
# row 280 of 10440
# row 300 of 10440
# ran into a nan.
# row 320 of 10440
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# row 340 of 10440
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ran into a nan.
# ...
